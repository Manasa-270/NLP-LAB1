# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa-270/NLP-LAB1/blob/main/NLPLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
input =" Hi I am Manasa. Hru "
output1 = word_tokenize(input)
print(output1)
output2 = sent_tokenize(input)
print(output2)
# Out:
# ['Hi', 'I', 'am', 'Manasa', '.', 'Hru']
# [' Hi I am Manasa.', 'Hru']

# %%
# !pip install -U spacy

# %%
# !pip install spacy

# %%
# !python -m download en_core_web_sm
# Out:
# /usr/bin/python3: No module named download

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
input = "This is the second session"
doc = nlp(input)

# %%
for token in doc:
 print(token)
# Out:
# This
# is
# the
# second
# session

# %%
for sent in doc.sents:
  print(sent)
# Out:
# This is the second session

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
import en_core_web_sm
nlp = en_core_web_sm.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])
# Out:
# [('This', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]
